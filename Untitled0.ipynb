# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhattarch/katacoda-scenarios/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !man hier
# Out:
# HIER(7)                    Linux Programmer's Manual                   HIER(7)
#
# E
#        hier - description of the filesystem hierarchy
#
# N
#        A typical Linux system has, among others, the following directories:
#
# /      This  is  the  root  directory.   This  is  where the whole tree
#               starts.
#
# n   This directory contains executable programs which are needed  in
#               single user mode and to bring the system up or repair it.
#
# t  Contains static files for the boot loader.  This directory holds
#               only the files which are needed during the  boot  process.   The
# n and
# c.  The operating system kernel (initrd for example) must  be
# t.
#
# v   Special  or  device files, which refer to physical devices.  See
# d(1).
#
# c   Contains configuration files which are  local  to  the  machine.
#               Some larger software packages, like X11, can have their own sub‐
# c.  Site-wide configuration  files  may  be
# ...

# %%
from google.colab import drive
drive.mount('/mnt/gdrive')
# Out:
# Mounted at /mnt/gdrive

# %%
# %cd /var
# %ls
# Out:
# /var
# backups/  colab/  local/  log/   opt/  spool/
# cache/    lib/    lock@   mail/  run@  tmp/

# %%
Backup = [
    "bin",
    "etc",
    "home",
    "lib",
    "lib32",
    "lib64",
    "opt",
    "usr\/bin",
    "usr\/games",
    "usr\/include",
    "usr\/lib",
    "usr\/lib32",
    "usr\/share",
    "var\/lib",
    "var\/spool"
]
drive = "\/mnt\/gdrive\/My\\ Drive\/ubuntu"
# %mkdir $drive
# %mkdir $drive/usr
# %mkdir $drive/var
for file in Backup:
    # %cp -r /$file $drive/$file
    # !echo $file
# Out:
# mkdir: cannot create directory ‘/mnt/gdrive/My Drive/ubuntu’: File exists
# mkdir: cannot create directory ‘/mnt/gdrive/My Drive/ubuntu/usr’: File exists
# bin
# etc
# home
# lib
# lib32
# lib64
# opt
# usr/bin
# usr/games
# usr/include
# usr/lib
# usr/lib32
# usr/share
# var/lib
# var/spool
